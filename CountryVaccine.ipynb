# %%
import pandas as pd
import numpy as np

# %%
vaccineData = pd.read_csv('C:/Users/pavan/Downloads/country_vaccination_stats.csv')

# %%
vaccineData
# Out:
#         country        date  daily_vaccinations  \
# 0     Argentina  12/29/2020                 NaN
# 1     Argentina  12/30/2020             15656.0
# 2     Argentina  12/31/2020             15656.0
# 3     Argentina    1/1/2021             11070.0
# 4     Argentina    1/2/2021              8776.0
# ...         ...         ...                 ...
# 1497      Wales   1/20/2021             11105.0
# 1498      Wales   1/21/2021             12318.0
# 1499      Wales   1/22/2021             15148.0
# 1500      Wales   1/23/2021             17371.0
# 1501      Wales   1/24/2021             17063.0
#
#                                  vaccines
# 0                               Sputnik V
# 1                               Sputnik V
# 2                               Sputnik V
# 3                               Sputnik V
# 4                               Sputnik V
# ...                                   ...
# 1497  Oxford/AstraZeneca, Pfizer/BioNTech
# ...

# %%
vaccineData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1502 entries, 0 to 1501
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             1502 non-null   object
#  1   date                1502 non-null   object
#  2   daily_vaccinations  1442 non-null   float64
#  3   vaccines            1502 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 47.1+ KB

# %%
vaccineData['daily_vaccinations'].isnull().values.sum()
# Out:
# 60

# %%
vaccineData.describe()
# Out:
#        daily_vaccinations
# count        1.442000e+03
# mean         4.334959e+04
# std          1.165367e+05
# min          1.000000e+00
# 25%          1.659750e+03
# 50%          5.567000e+03
# 75%          2.797975e+04
# max          1.126251e+06

# %%
min_value = vaccineData.groupby('country').daily_vaccinations.min()
min_value
# Out:
# country
# Argentina                 6483.0
# Austria                   3368.0
# Bahrain                    943.0
# Belgium                      1.0
# Brazil                     112.0
# Bulgaria                   472.0
# Canada                     866.0
# Chile                       51.0
# China                   187500.0
# Costa Rica                 240.0
# Croatia                    989.0
# Cyprus                     534.0
# Czechia                   1822.0
# Denmark                   1994.0
# Ecuador                    108.0
# England                  37625.0
# Estonia                    309.0
# Finland                    459.0
# France                    5000.0
# Germany                  19721.0
# Gibraltar                  520.0
# Greece                     549.0
# Hungary                   1339.0
# Iceland                     63.0
# India                   112150.0
# Indonesia                11823.0
# Ireland                    550.0
# Isle of Man                 90.0
# ...

# %%
vaccineData["daily_vaccinations"]=vaccineData.groupby("country")['daily_vaccinations'].transform(lambda x: x.fillna(x.min()))
    
vaccineData.loc[750 ,'daily_vaccinations'] = 0
#print(vaccineData['daily_vaccinations'])

vaccineData.head(50)
# Out:
#       country        date  daily_vaccinations                    vaccines
# 0   Argentina  12/29/2020              6483.0                   Sputnik V
# 1   Argentina  12/30/2020             15656.0                   Sputnik V
# 2   Argentina  12/31/2020             15656.0                   Sputnik V
# 3   Argentina    1/1/2021             11070.0                   Sputnik V
# 4   Argentina    1/2/2021              8776.0                   Sputnik V
# 5   Argentina    1/3/2021              7400.0                   Sputnik V
# 6   Argentina    1/4/2021              6483.0                   Sputnik V
# 7   Argentina    1/5/2021              7984.0                   Sputnik V
# 8   Argentina    1/6/2021              8173.0                   Sputnik V
# 9   Argentina    1/7/2021              8363.0                   Sputnik V
# 10  Argentina    1/8/2021             10519.0                   Sputnik V
# 11  Argentina    1/9/2021             11942.0                   Sputnik V
# ...

# %%
vaccineData.to_csv('newfile.csv',index=False)

# %%
vaccineData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1502 entries, 0 to 1501
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             1502 non-null   object
#  1   date                1502 non-null   object
#  2   daily_vaccinations  1502 non-null   float64
#  3   vaccines            1502 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 47.1+ KB

# %%
# %pwd
# Out:
# 'C:\\Users\\pavan\\Downloads'
